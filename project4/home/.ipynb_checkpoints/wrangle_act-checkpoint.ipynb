# %% [markdown]
# ## Gather

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import requests
import seaborn as sns

# %% [markdown]
# #### The tweet image predictions

# %%
url = 'https://d17h27t6h515a5.cloudfront.net/topher/2017/August/599fd2ad_image-predictions/image-predictions.tsv'

with open('image_predictions.tsv', 'wb') as file:
    file.write(requests.get(url).content)

# %%
image_prediction = pd.read_csv('image_predictions.tsv', sep='\t')
image_prediction.head()
# Out:
#              tweet_id                                          jpg_url  \
# 0  666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1  666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2  666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3  666044226329800704  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4  666049248165822465  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
#
#    img_num                      p1   p1_conf  p1_dog                  p2  \
# 0        1  Welsh_springer_spaniel  0.465074    True              collie
# 1        1                 redbone  0.506826    True  miniature_pinscher
# 2        1         German_shepherd  0.596461    True            malinois
# 3        1     Rhodesian_ridgeback  0.408143    True             redbone
# 4        1      miniature_pinscher  0.560311    True          Rottweiler
#
#     p2_conf  p2_dog                   p3   p3_conf  p3_dog
# 0  0.156665    True    Shetland_sheepdog  0.061428    True
# 1  0.074192    True  Rhodesian_ridgeback  0.072010    True
# 2  0.138584    True           bloodhound  0.116197    True
# 3  0.360687    True   miniature_pinscher  0.222752    True
# 4  0.243682    True             Doberman  0.154629    True

# %% [markdown]
# #### The WeRateDogs Twitter archive

# %%
twitter_archive = pd.read_csv('twitter-archive-enhanced.csv')
twitter_archive.head()
# Out:
#              tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0  892420643555336193                    NaN                  NaN
# 1  892177421306343426                    NaN                  NaN
# 2  891815181378084864                    NaN                  NaN
# 3  891689557279858688                    NaN                  NaN
# 4  891327558926688256                    NaN                  NaN
#
#                    timestamp  \
# 0  2017-08-01 16:23:56 +0000
# 1  2017-08-01 00:17:27 +0000
# 2  2017-07-31 00:18:03 +0000
# 3  2017-07-30 15:58:51 +0000
# 4  2017-07-29 16:00:24 +0000
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://twitter.com/download/iphone" r...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://twitter.com/download/iphone" r...
#
#                                                 text  retweeted_status_id  \
# 0  This is Phineas. He's a mystical boy. Only eve...                  NaN
# 1  This is Tilly. She's just checking pup on you....                  NaN
# 2  This is Archie. He is a rare Norwegian Pouncin...                  NaN
# 3  This is Darla. She commenced a snooze mid meal...                  NaN
# 4  This is Franklin. He would like you to stop ca...                  NaN
#
#    retweeted_status_user_id retweeted_status_timestamp  \
# 0                       NaN                        NaN
# 1                       NaN                        NaN
# 2                       NaN                        NaN
# 3                       NaN                        NaN
# 4                       NaN                        NaN
#
#                                        expanded_urls  rating_numerator  \
# 0  https://twitter.com/dog_rates/status/892420643...                13
# 1  https://twitter.com/dog_rates/status/892177421...                13
# 2  https://twitter.com/dog_rates/status/891815181...                12
# 3  https://twitter.com/dog_rates/status/891689557...                13
# 4  https://twitter.com/dog_rates/status/891327558...                12
#
#    rating_denominator      name doggo floofer pupper puppo
# 0                  10   Phineas  None    None   None  None
# 1                  10     Tilly  None    None   None  None
# 2                  10    Archie  None    None   None  None
# 3                  10     Darla  None    None   None  None
# 4                  10  Franklin  None    None   None  None

# %% [markdown]
# #### tweet_json from twitter API

# %%
import tweepy
from tweepy import OAuthHandler
import json
from timeit import default_timer as timer

# Query Twitter API for each tweet in the Twitter archive and save JSON in a text file
# These are hidden to comply with Twitter's API terms and conditions
consumer_key = 'HIDDEN'
consumer_secret = 'HIDDEN'
access_token = 'HIDDEN'
access_secret = 'HIDDEN'

auth = OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_secret)

api = tweepy.API(auth, wait_on_rate_limit=True)

# NOTE TO STUDENT WITH MOBILE VERIFICATION ISSUES:
# df_1 is a DataFrame with the twitter_archive_enhanced.csv file. You may have to
# change line 17 to match the name of your DataFrame with twitter_archive_enhanced.csv
# NOTE TO REVIEWER: this student had mobile verification issues so the following
# Twitter API code was sent to this student from a Udacity instructor
# Tweet IDs for which to gather additional data via Twitter's API
tweet_ids = df_1.tweet_id.values
len(tweet_ids)

# Query Twitter's API for JSON data for each tweet ID in the Twitter archive
count = 0
fails_dict = {}
start = timer()
# Save each tweet's returned JSON as a new line in a .txt file
with open('tweet_json.txt', 'w') as outfile:
    # This loop will likely take 20-30 minutes to run because of Twitter's rate limit
    for tweet_id in tweet_ids:
        count += 1
        print(str(count) + ": " + str(tweet_id))
        try:
            tweet = api.get_status(tweet_id, tweet_mode='extended')
            print("Success")
            json.dump(tweet._json, outfile)
            outfile.write('\n')
        except tweepy.TweepError as e:
            print("Fail")
            fails_dict[tweet_id] = e
            pass
end = timer()
print(end - start)
print(fails_dict)

# %%
import json
selected_cols = []
with open('tweet-json.txt', 'r') as json_file:
    for line in json_file:
        data = json.loads(line)
        selected_cols.append({'tweet_id': data['id'],
                    'favorites': data['favorite_count'],
                    'retweets': data['retweet_count']})
tweet = pd.DataFrame(selected_cols, columns=['tweet_id','favorites','retweets'])

# %%
tweet.head()
# Out:
#              tweet_id  favorites  retweets
# 0  892420643555336193      39467      8853
# 1  892177421306343426      33819      6514
# 2  891815181378084864      25461      4328
# 3  891689557279858688      42908      8964
# 4  891327558926688256      41048      9774

# %% [markdown]
# ## Assess

# %% [markdown]
# #### Visually

# %%
image_prediction.head()
# Out:
#              tweet_id                                          jpg_url  \
# 0  666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1  666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2  666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3  666044226329800704  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4  666049248165822465  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
#
#    img_num                      p1   p1_conf  p1_dog                  p2  \
# 0        1  Welsh_springer_spaniel  0.465074    True              collie
# 1        1                 redbone  0.506826    True  miniature_pinscher
# 2        1         German_shepherd  0.596461    True            malinois
# 3        1     Rhodesian_ridgeback  0.408143    True             redbone
# 4        1      miniature_pinscher  0.560311    True          Rottweiler
#
#     p2_conf  p2_dog                   p3   p3_conf  p3_dog
# 0  0.156665    True    Shetland_sheepdog  0.061428    True
# 1  0.074192    True  Rhodesian_ridgeback  0.072010    True
# 2  0.138584    True           bloodhound  0.116197    True
# 3  0.360687    True   miniature_pinscher  0.222752    True
# 4  0.243682    True             Doberman  0.154629    True

# %%
twitter_archive.head()
# Some columns have a lot of NaN
# Some column names are not clear in terms of what they represent
# floofer,doggo, puppo,and pupper should be variables instead of column names
# df_pred and df_tweet contain urls, 
# I should check if they provide the same information
# Out:
#              tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0  892420643555336193                    NaN                  NaN
# 1  892177421306343426                    NaN                  NaN
# 2  891815181378084864                    NaN                  NaN
# 3  891689557279858688                    NaN                  NaN
# 4  891327558926688256                    NaN                  NaN
#
#                    timestamp  \
# 0  2017-08-01 16:23:56 +0000
# 1  2017-08-01 00:17:27 +0000
# 2  2017-07-31 00:18:03 +0000
# 3  2017-07-30 15:58:51 +0000
# 4  2017-07-29 16:00:24 +0000
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://twitter.com/download/iphone" r...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://twitter.com/download/iphone" r...
#
#                                                 text  retweeted_status_id  \
# 0  This is Phineas. He's a mystical boy. Only eve...                  NaN
# 1  This is Tilly. She's just checking pup on you....                  NaN
# 2  This is Archie. He is a rare Norwegian Pouncin...                  NaN
# 3  This is Darla. She commenced a snooze mid meal...                  NaN
# 4  This is Franklin. He would like you to stop ca...                  NaN
#
#    retweeted_status_user_id retweeted_status_timestamp  \
# 0                       NaN                        NaN
# 1                       NaN                        NaN
# 2                       NaN                        NaN
# 3                       NaN                        NaN
# 4                       NaN                        NaN
#
#                                        expanded_urls  rating_numerator  \
# 0  https://twitter.com/dog_rates/status/892420643...                13
# 1  https://twitter.com/dog_rates/status/892177421...                13
# 2  https://twitter.com/dog_rates/status/891815181...                12
# 3  https://twitter.com/dog_rates/status/891689557...                13
# 4  https://twitter.com/dog_rates/status/891327558...                12
#
#    rating_denominator      name doggo floofer pupper puppo
# 0                  10   Phineas  None    None   None  None
# 1                  10     Tilly  None    None   None  None
# 2                  10    Archie  None    None   None  None
# 3                  10     Darla  None    None   None  None
# 4                  10  Franklin  None    None   None  None

# %%
tweet.head()
# Out:
#              tweet_id  favorites  retweets
# 0  892420643555336193      39467      8853
# 1  892177421306343426      33819      6514
# 2  891815181378084864      25461      4328
# 3  891689557279858688      42908      8964
# 4  891327558926688256      41048      9774

# %%
# The three tables are based on the same tweet_id column, 
# they could be combined to a single table.

# %% [markdown]
# ## Clean and assess(programatically)

# %%
df_pred = image_prediction.copy()
df_tweet = twitter_archive.copy()
basic_tweet = tweet.copy()

# %% [markdown]
# ### Completeness

# %%
print(df_tweet.shape)
# Out:
# (2356, 17)

# %%
df_tweet.isnull().sum() # some of the columns are almost compltely missing and are not useful
# the expanded_urls has only 59 missing values, maybe I can try to fix it
# Out:
# tweet_id                         0
# in_reply_to_status_id         2278
# in_reply_to_user_id           2278
# timestamp                        0
# source                           0
# text                             0
# retweeted_status_id           2175
# retweeted_status_user_id      2175
# retweeted_status_timestamp    2175
# expanded_urls                   59
# rating_numerator                 0
# rating_denominator               0
# name                             0
# doggo                            0
# floofer                          0
# pupper                           0
# puppo                            0
# dtype: int64

# %%
df_tweet['expanded_urls']# take a look at this expanded_urls column
# Out:
# 0       https://twitter.com/dog_rates/status/892420643...
# 1       https://twitter.com/dog_rates/status/892177421...
# 2       https://twitter.com/dog_rates/status/891815181...
# 3       https://twitter.com/dog_rates/status/891689557...
# 4       https://twitter.com/dog_rates/status/891327558...
# 5       https://twitter.com/dog_rates/status/891087950...
# 6       https://gofundme.com/ydvmve-surgery-for-jax,ht...
# 7       https://twitter.com/dog_rates/status/890729181...
# 8       https://twitter.com/dog_rates/status/890609185...
# 9       https://twitter.com/dog_rates/status/890240255...
# 10      https://twitter.com/dog_rates/status/890006608...
# 11      https://twitter.com/dog_rates/status/889880896...
# 12      https://twitter.com/dog_rates/status/889665388...
# 13      https://twitter.com/dog_rates/status/889638837...
# 14      https://twitter.com/dog_rates/status/889531135...
# 15      https://twitter.com/dog_rates/status/889278841...
# 16      https://twitter.com/dog_rates/status/888917238...
# 17      https://twitter.com/dog_rates/status/888804989...
# 18      https://twitter.com/dog_rates/status/888554962...
# 19      https://twitter.com/dog_rates/status/887473957...
# 20      https://twitter.com/dog_rates/status/888078434...
# 21      https://twitter.com/dog_rates/status/887705289...
# 22      https://twitter.com/dog_rates/status/887517139...
# 23      https://twitter.com/dog_rates/status/887473957...
# 24      https://twitter.com/dog_rates/status/887343217...
# 25      https://twitter.com/dog_rates/status/887101392...
# 26      https://twitter.com/dog_rates/status/886983233...
# 27      https://www.gofundme.com/mingusneedsus,https:/...
# 28      https://twitter.com/dog_rates/status/886680336...
# 29      https://twitter.com/dog_rates/status/886366144...
#                               ...
# 2326    https://twitter.com/dog_rates/status/666411507...
# 2327    https://twitter.com/dog_rates/status/666407126...
# 2328    https://twitter.com/dog_rates/status/666396247...
# 2329    https://twitter.com/dog_rates/status/666373753...
# 2330    https://twitter.com/dog_rates/status/666362758...
# 2331    https://twitter.com/dog_rates/status/666353288...
# 2332    https://twitter.com/dog_rates/status/666345417...
# 2333    https://twitter.com/dog_rates/status/666337882...
# 2334    https://twitter.com/dog_rates/status/666293911...
# 2335    https://twitter.com/dog_rates/status/666287406...
# 2336    https://twitter.com/dog_rates/status/666273097...
# 2337    https://twitter.com/dog_rates/status/666268910...
# 2338    https://twitter.com/dog_rates/status/666104133...
# 2339    https://twitter.com/dog_rates/status/666102155...
# 2340    https://twitter.com/dog_rates/status/666099513...
# 2341    https://twitter.com/dog_rates/status/666094000...
# 2342    https://twitter.com/dog_rates/status/666082916...
# 2343    https://twitter.com/dog_rates/status/666073100...
# 2344    https://twitter.com/dog_rates/status/666071193...
# 2345    https://twitter.com/dog_rates/status/666063827...
# 2346    https://twitter.com/dog_rates/status/666058600...
# 2347    https://twitter.com/dog_rates/status/666057090...
# 2348    https://twitter.com/dog_rates/status/666055525...
# 2349    https://twitter.com/dog_rates/status/666051853...
# 2350    https://twitter.com/dog_rates/status/666050758...
# 2351    https://twitter.com/dog_rates/status/666049248...
# 2352    https://twitter.com/dog_rates/status/666044226...
# 2353    https://twitter.com/dog_rates/status/666033412...
# 2354    https://twitter.com/dog_rates/status/666029285...
# 2355    https://twitter.com/dog_rates/status/666020888...
# Name: expanded_urls, Length: 2356, dtype: object

# %%
df_tweet.expanded_urls[0][-27:]
# Out:
# '/892420643555336193/photo/1'

# %%
df_tweet.tweet_id[0]
#The pattern seems to be https://twitter.com/dog_rates/status/ + tweet_id + /photo/1
# so I can fill in the missing value with this pattern
# Out:
# 892420643555336193

# %% [markdown]
# #### `df_tweet`: 59 missing values in `expanded_urls` column

# %% [markdown]
# ##### Define
# Fill in the missing values with the pattern: https://twitter.com/dog_rates/status/ + `tweet_id` + /photo/1

# %% [markdown]
# ##### Code

# %%
def fill_in_urls(row):
    if pd.isnull(row['expanded_urls']):
        row['expanded_urls']= 'https://twitter.com/dog_rates/status/'+str(row['tweet_id'])+'/photo/1'
    else:
        row['expanded_urls']= row['expanded_urls']
    return row['expanded_urls']

df_tweet['expanded_urls']=df_tweet.apply(lambda row: fill_in_urls(row),axis=1)

# %% [markdown]
# ##### Test

# %%
df_tweet.expanded_urls[30], df_tweet.tweet_id[30]
# row30 was missing value, and now it has an url
# the number part of the url matches its id
# Out:
# ('https://twitter.com/dog_rates/status/886267009285017600/photo/1',
#  886267009285017600)

# %% [markdown]
# #### df_pred

# %%
df_pred.isnull().sum()# no missing value
# Out:
# tweet_id    0
# jpg_url     0
# img_num     0
# p1          0
# p1_conf     0
# p1_dog      0
# p2          0
# p2_conf     0
# p2_dog      0
# p3          0
# p3_conf     0
# p3_dog      0
# dtype: int64

# %% [markdown]
# #### basic_tweet

# %%
basic_tweet.isnull().sum()# no missing value
# Out:
# tweet_id     0
# favorites    0
# retweets     0
# dtype: int64

# %% [markdown]
# ***

# %% [markdown]
# ### Tidiness

# %%
# doggo, floofer, pupper, puppo can be put into one column called dog_stage
df_tweet.columns
# Out:
# Index(['tweet_id', 'in_reply_to_status_id', 'in_reply_to_user_id', 'timestamp',
#        'source', 'text', 'retweeted_status_id', 'retweeted_status_user_id',
#        'retweeted_status_timestamp', 'expanded_urls', 'rating_numerator',
#        'rating_denominator', 'name', 'doggo', 'floofer', 'pupper', 'puppo'],
#       dtype='object')

# %%
len(df_tweet[(df_tweet.doggo=='None')&(df_tweet.floofer=='None')&
             (df_tweet.pupper=='None')&(df_tweet.puppo=='None')])
# in most of row, this dog stage is missing
# Out:
# 1976

# %% [markdown]
# #### `df_tweet`: doggo, floofer, pupper, puppo should be the variables instead of column names

# %% [markdown]
# ##### Define
# Put doggo, floofer, pupper, puppo into one column called dog_stage

# %% [markdown]
# ##### Code

# %%
# create a new column "dog_stage" and indicate which stage the dog is, including "doggo","floofer","pupper", or"puppo"
def dog_stage(row):
    if row['doggo']!='None':
        result=row['doggo']
    elif row['floofer']!='None':
        result=row['floofer']
    elif row['pupper']!='None':
        result=row['pupper']
    elif row['puppo']!='None':
        result=row['puppo']
    else:
        result="None"
    return result
df_tweet['dog_stage']=df_tweet.apply(lambda row:dog_stage(row),axis=1)

# %%
# the puppo column with non-None value does not equal to the new dog_stage column with the value "puppo"
(df_tweet[df_tweet.puppo!='None']['puppo']).equals(df_tweet[df_tweet.dog_stage=='puppo']['dog_stage'])
# Out:
# False

# %%
puppo=df_tweet[df_tweet.puppo!='None'].copy()
puppo.loc[puppo.dog_stage!='puppo']#Those two columns are not equal because of duplicated stages.
# row191 is both doggo and puppo
# Out:
#                tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 191  855851453814013952                    NaN                  NaN
#
#                      timestamp  \
# 191  2017-04-22 18:31:02 +0000
#
#                                                 source  \
# 191  <a href="http://twitter.com/download/iphone" r...
#
#                                                   text  retweeted_status_id  \
# 191  Here's a puppo participating in the #ScienceMa...                  NaN
#
#      retweeted_status_user_id retweeted_status_timestamp  \
# 191                       NaN                        NaN
#
#                                          expanded_urls  rating_numerator  \
# 191  https://twitter.com/dog_rates/status/855851453...                13
#
#      rating_denominator  name  doggo floofer pupper  puppo dog_stage
# 191                  10  None  doggo    None   None  puppo     doggo

# %%
# give it a new category called duplicated
df_tweet.loc[191,'dog_stage']='duplicated'

# %%
df_tweet.loc[191,'dog_stage']
# Out:
# 'duplicated'

# %%
# the floofer column with non-None value does not equal to the new dog_stage column with the value "floofer"
(df_tweet[df_tweet.floofer!='None']['floofer']).equals(df_tweet[df_tweet.dog_stage=='floofer']['dog_stage'])
# Out:
# False

# %%
floofer=df_tweet[df_tweet.floofer!='None'].copy()
floofer.loc[floofer.dog_stage!='floofer']
# floofer has duplication too
# row200 is both doggo and floofer
# Out:
#                tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 200  854010172552949760                    NaN                  NaN
#
#                      timestamp  \
# 200  2017-04-17 16:34:26 +0000
#
#                                                 source  \
# 200  <a href="http://twitter.com/download/iphone" r...
#
#                                                   text  retweeted_status_id  \
# 200  At first I thought this was a shy doggo, but i...                  NaN
#
#      retweeted_status_user_id retweeted_status_timestamp  \
# 200                       NaN                        NaN
#
#                                          expanded_urls  rating_numerator  \
# 200  https://twitter.com/dog_rates/status/854010172...                11
#
#      rating_denominator  name  doggo  floofer pupper puppo dog_stage
# 200                  10  None  doggo  floofer   None  None     doggo

# %%
# give it the same 'duplicated' value
df_tweet.loc[200,'dog_stage']='duplicated'

# %%
df_tweet.loc[200,'dog_stage']
# Out:
# 'duplicated'

# %%
# the pupper column with non-None value does not equal to the new dog_stage column with the value "pupper"
(df_tweet[df_tweet.pupper!='None']['pupper']).equals(df_tweet[df_tweet.dog_stage=='pupper']['dog_stage'])
# Out:
# False

# %%
pupper=df_tweet[df_tweet.pupper!='None'].copy()
pupper_index=pupper.loc[pupper.dog_stage!='pupper'].index
df_tweet.loc[pupper_index,'dog_stage']='duplicated'
# pupper has many rows of duplication, I give them the value "duplicated" too since they are both pupper and doggo

# %%
# look fine when examined manually
df_tweet.loc[df_tweet.dog_stage=='duplicated']
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 191   855851453814013952                    NaN                  NaN
# 200   854010172552949760                    NaN                  NaN
# 460   817777686764523521                    NaN                  NaN
# 531   808106460588765185                    NaN                  NaN
# 565   802265048156610565           7.331095e+17         4.196984e+09
# 575   801115127852503040                    NaN                  NaN
# 705   785639753186217984                    NaN                  NaN
# 733   781308096455073793                    NaN                  NaN
# 778   775898661951791106                    NaN                  NaN
# 822   770093767776997377                    NaN                  NaN
# 889   759793422261743616                    NaN                  NaN
# 956   751583847268179968                    NaN                  NaN
# 1063  741067306818797568                    NaN                  NaN
# 1113  733109485275860992                    NaN                  NaN
#
#                       timestamp  \
# 191   2017-04-22 18:31:02 +0000
# 200   2017-04-17 16:34:26 +0000
# 460   2017-01-07 16:59:28 +0000
# 531   2016-12-12 00:29:28 +0000
# 565   2016-11-25 21:37:47 +0000
# 575   2016-11-22 17:28:25 +0000
# 705   2016-10-11 00:34:48 +0000
# 733   2016-09-29 01:42:20 +0000
# 778   2016-09-14 03:27:11 +0000
# 822   2016-08-29 03:00:36 +0000
# 889   2016-07-31 16:50:42 +0000
# 956   2016-07-09 01:08:47 +0000
# 1063  2016-06-10 00:39:48 +0000
# 1113  2016-05-19 01:38:16 +0000
#
#                                                  source  \
# 191   <a href="http://twitter.com/download/iphone" r...
# 200   <a href="http://twitter.com/download/iphone" r...
# 460   <a href="http://twitter.com/download/iphone" r...
# 531   <a href="http://twitter.com/download/iphone" r...
# 565   <a href="http://twitter.com/download/iphone" r...
# 575   <a href="http://twitter.com/download/iphone" r...
# 705   <a href="http://twitter.com/download/iphone" r...
# 733   <a href="http://vine.co" rel="nofollow">Vine -...
# 778   <a href="http://twitter.com/download/iphone" r...
# 822   <a href="http://twitter.com/download/iphone" r...
# 889   <a href="http://twitter.com/download/iphone" r...
# 956   <a href="http://twitter.com/download/iphone" r...
# 1063  <a href="http://twitter.com/download/iphone" r...
# 1113  <a href="http://twitter.com/download/iphone" r...
#
#                                                    text  retweeted_status_id  \
# 191   Here's a puppo participating in the #ScienceMa...                  NaN
# 200   At first I thought this was a shy doggo, but i...                  NaN
# 460   This is Dido. She's playing the lead role in "...                  NaN
# 531   Here we have Burke (pupper) and Dexter (doggo)...                  NaN
# 565   Like doggo, like pupper version 2. Both 11/10 ...                  NaN
# 575   This is Bones. He's being haunted by another d...                  NaN
# 705   This is Pinot. He's a sophisticated doggo. You...                  NaN
# 733   Pupper butt 1, Doggo 0. Both 12/10 https://t.c...                  NaN
# 778   RT @dog_rates: Like father (doggo), like son (...         7.331095e+17
# 822   RT @dog_rates: This is just downright precious...         7.410673e+17
# 889   Meet Maggie &amp; Lila. Maggie is the doggo, L...                  NaN
# 956   Please stop sending it pictures that don't eve...                  NaN
# 1063  This is just downright precious af. 12/10 for ...                  NaN
# 1113  Like father (doggo), like son (pupper). Both 1...                  NaN
#
#       retweeted_status_user_id retweeted_status_timestamp  \
# 191                        NaN                        NaN
# 200                        NaN                        NaN
# 460                        NaN                        NaN
# 531                        NaN                        NaN
# 565                        NaN                        NaN
# 575                        NaN                        NaN
# 705                        NaN                        NaN
# 733                        NaN                        NaN
# 778               4.196984e+09  2016-05-19 01:38:16 +0000
# 822               4.196984e+09  2016-06-10 00:39:48 +0000
# 889                        NaN                        NaN
# 956                        NaN                        NaN
# 1063                       NaN                        NaN
# 1113                       NaN                        NaN
#
#                                           expanded_urls  rating_numerator  \
# 191   https://twitter.com/dog_rates/status/855851453...                13
# 200   https://twitter.com/dog_rates/status/854010172...                11
# 460   https://twitter.com/dog_rates/status/817777686...                13
# 531   https://twitter.com/dog_rates/status/808106460...                12
# 565   https://twitter.com/dog_rates/status/802265048...                11
# 575   https://twitter.com/dog_rates/status/801115127...                12
# 705   https://twitter.com/dog_rates/status/785639753...                10
# 733                       https://vine.co/v/5rgu2Law2ut                12
# 778   https://twitter.com/dog_rates/status/733109485...                12
# 822   https://twitter.com/dog_rates/status/741067306...                12
# 889   https://twitter.com/dog_rates/status/759793422...                12
# 956   https://twitter.com/dog_rates/status/751583847...                 5
# 1063  https://twitter.com/dog_rates/status/741067306...                12
# 1113  https://twitter.com/dog_rates/status/733109485...                12
#
#       rating_denominator    name  doggo  floofer  pupper  puppo   dog_stage
# 191                   10    None  doggo     None    None  puppo  duplicated
# 200                   10    None  doggo  floofer    None   None  duplicated
# 460                   10    Dido  doggo     None  pupper   None  duplicated
# 531                   10    None  doggo     None  pupper   None  duplicated
# 565                   10    None  doggo     None  pupper   None  duplicated
# 575                   10   Bones  doggo     None  pupper   None  duplicated
# 705                   10   Pinot  doggo     None  pupper   None  duplicated
# 733                   10    None  doggo     None  pupper   None  duplicated
# 778                   10    None  doggo     None  pupper   None  duplicated
# 822                   10    just  doggo     None  pupper   None  duplicated
# 889                   10  Maggie  doggo     None  pupper   None  duplicated
# 956                   10    None  doggo     None  pupper   None  duplicated
# 1063                  10    just  doggo     None  pupper   None  duplicated
# 1113                  10    None  doggo     None  pupper   None  duplicated

# %%
len(df_tweet.loc[df_tweet.dog_stage=='duplicated'])
# Out:
# 14

# %%
# it should be False because doggo column should match "doggo" plus "duplicated" in dog_stage column
(df_tweet[df_tweet.doggo!='None']['doggo']).equals(df_tweet[df_tweet.dog_stage=='doggo']['dog_stage'])
# Out:
# False

# %%
df_tweet.drop(columns=['doggo','floofer','puppo','pupper'],inplace=True)

# %% [markdown]
# ##### Test

# %%
# At first, df_tweet has 17 columns, I created a dog_stage column and drop 4 columns. The number of columns matches 17+1-4=14
df_tweet.shape
# Out:
# (2356, 14)

# %%
df_tweet.sample(10)
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 512   811744202451197953                    NaN                  NaN
# 168   859607811541651456                    NaN                  NaN
# 17    888804989199671297                    NaN                  NaN
# 1141  727644517743104000                    NaN                  NaN
# 490   813812741911748608                    NaN                  NaN
# 1796  677301033169788928                    NaN                  NaN
# 639   793256262322548741                    NaN                  NaN
# 337   832397543355072512                    NaN                  NaN
# 2259  667550904950915073                    NaN                  NaN
# 1681  681981167097122816                    NaN                  NaN
#
#                       timestamp  \
# 512   2016-12-22 01:24:33 +0000
# 168   2017-05-03 03:17:27 +0000
# 17    2017-07-22 16:56:37 +0000
# 1141  2016-05-03 23:42:26 +0000
# 490   2016-12-27 18:24:12 +0000
# 1796  2015-12-17 01:35:24 +0000
# 639   2016-11-01 01:00:05 +0000
# 337   2017-02-17 01:13:34 +0000
# 2259  2015-11-20 03:51:52 +0000
# 1681  2015-12-29 23:32:35 +0000
#
#                                                  source  \
# 512   <a href="http://twitter.com/download/iphone" r...
# 168   <a href="http://twitter.com/download/iphone" r...
# 17    <a href="http://twitter.com/download/iphone" r...
# 1141  <a href="http://twitter.com/download/iphone" r...
# 490   <a href="http://twitter.com/download/iphone" r...
# 1796  <a href="http://twitter.com/download/iphone" r...
# 639   <a href="http://twitter.com/download/iphone" r...
# 337   <a href="http://twitter.com/download/iphone" r...
# 2259  <a href="http://twitter.com" rel="nofollow">Tw...
# 1681  <a href="http://twitter.com/download/iphone" r...
#
#                                                    text  retweeted_status_id  \
# 512   This is Halo. She likes watermelon. 13/10 http...                  NaN
# 168   Sorry for the lack of posts today. I came home...                  NaN
# 17    This is Zeke. He has a new stick. Very proud o...                  NaN
# 1141  Here's a doggo struggling to cope with the win...                  NaN
# 490   Meet Gary, Carrie Fisher's dog. Idk what I can...                  NaN
# 1796  This is Juckson. He's totally on his way to a ...                  NaN
# 639   Oh h*ck look at this spookling right here. Fri...                  NaN
# 337   This is Eevee. She wants to see how you're doi...                  NaN
# 2259  RT @dogratingrating: Exceptional talent. Origi...         6.675487e+17
# 1681  This is Jimothy. He's a Trinidad Poliwhirl. Fa...                  NaN
#
#       retweeted_status_user_id retweeted_status_timestamp  \
# 512                        NaN                        NaN
# 168                        NaN                        NaN
# 17                         NaN                        NaN
# 1141                       NaN                        NaN
# 490                        NaN                        NaN
# 1796                       NaN                        NaN
# 639                        NaN                        NaN
# 337                        NaN                        NaN
# 2259              4.296832e+09  2015-11-20 03:43:06 +0000
# 1681                       NaN                        NaN
#
#                                           expanded_urls  rating_numerator  \
# 512   https://twitter.com/dog_rates/status/811744202...                13
# 168   https://twitter.com/dog_rates/status/859607811...                13
# 17    https://twitter.com/dog_rates/status/888804989...                13
# 1141  https://twitter.com/dog_rates/status/727644517...                13
# 490   https://twitter.com/dog_rates/status/813812741...                14
# 1796  https://twitter.com/dog_rates/status/677301033...                 5
# 639   https://twitter.com/dog_rates/status/793256262...                12
# 337   https://twitter.com/dog_rates/status/832397543...                12
# 2259  https://twitter.com/dogratingrating/status/667...                12
# 1681  https://twitter.com/dog_rates/status/681981167...                12
#
#       rating_denominator     name dog_stage
# 512                   10     Halo      None
# 168                   10     None     puppo
# 17                    10     Zeke      None
# 1141                  10     None     doggo
# 490                   10     Gary      None
# 1796                  10  Juckson      None
# 639                   10     None      None
# 337                   10    Eevee      None
# 2259                  10     None      None
# 1681                  10  Jimothy      None

# %% [markdown]
# ***

# %%
df_tweet.text.iloc[0]
# Out:
# "This is Phineas. He's a mystical boy. Only ever appears in the hole of a donut. 13/10 https://t.co/MgUWQ76dJU"

# %% [markdown]
# #### `df_tweet`:  text column contain multiple information

# %% [markdown]
# ##### Define
# Remove urls at the end of this column

# %% [markdown]
# ##### Code

# %%
# there are text and url in text column while I only want the text, so I'll remove the urls
df_tweet['text'] = df_tweet.text.str.rsplit(n=1, expand=True)[0]

# %% [markdown]
# ##### Test

# %%
df_tweet['text'][0]
# Out:
# "This is Phineas. He's a mystical boy. Only ever appears in the hole of a donut. 13/10"

# %% [markdown]
# ***

# %% [markdown]
# #### The three tables can be one

# %%
df_pred.shape, df_tweet.shape, basic_tweet.shape
# de_pred has less rows than the other two
# Out:
# ((2075, 12), (2356, 14), (2354, 3))

# %% [markdown]
# ##### Define
# Combine the three tables using merge function

# %% [markdown]
# ##### Code

# %%
df = pd.merge(df_tweet, basic_tweet, on='tweet_id', how='outer')

# %%
df = pd.merge(df,df_pred, on='tweet_id',how='outer')

# %%
df.isnull().sum()
# Out:
# tweet_id                         0
# in_reply_to_status_id         2278
# in_reply_to_user_id           2278
# timestamp                        0
# source                           0
# text                             0
# retweeted_status_id           2175
# retweeted_status_user_id      2175
# retweeted_status_timestamp    2175
# expanded_urls                    0
# rating_numerator                 0
# rating_denominator               0
# name                             0
# dog_stage                        0
# favorites                        2
# retweets                         2
# jpg_url                        281
# img_num                        281
# p1                             281
# p1_conf                        281
# p1_dog                         281
# p2                             281
# p2_conf                        281
# p2_dog                         281
# p3                             281
# p3_conf                        281
# p3_dog                         281
# dtype: int64

# %%
# 'in_reply_to_status_id', 'in_reply_to_user_id' have many missing value and 
# they don't seem to be important in terms of analysis, so I'll get rid of them to make to dataframe
# looks cleaner
df.drop(columns=['in_reply_to_status_id','in_reply_to_user_id'],inplace=True)

# %% [markdown]
# ##### Test

# %%
df.head()
# Out:
#              tweet_id                  timestamp  \
# 0  892420643555336193  2017-08-01 16:23:56 +0000
# 1  892177421306343426  2017-08-01 00:17:27 +0000
# 2  891815181378084864  2017-07-31 00:18:03 +0000
# 3  891689557279858688  2017-07-30 15:58:51 +0000
# 4  891327558926688256  2017-07-29 16:00:24 +0000
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://twitter.com/download/iphone" r...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://twitter.com/download/iphone" r...
#
#                                                 text  retweeted_status_id  \
# 0  This is Phineas. He's a mystical boy. Only eve...                  NaN
# 1  This is Tilly. She's just checking pup on you....                  NaN
# 2  This is Archie. He is a rare Norwegian Pouncin...                  NaN
# 3  This is Darla. She commenced a snooze mid meal...                  NaN
# 4  This is Franklin. He would like you to stop ca...                  NaN
#
#    retweeted_status_user_id retweeted_status_timestamp  \
# 0                       NaN                        NaN
# 1                       NaN                        NaN
# 2                       NaN                        NaN
# 3                       NaN                        NaN
# 4                       NaN                        NaN
#
#                                        expanded_urls  rating_numerator  \
# 0  https://twitter.com/dog_rates/status/892420643...                13
# 1  https://twitter.com/dog_rates/status/892177421...                13
# 2  https://twitter.com/dog_rates/status/891815181...                12
# 3  https://twitter.com/dog_rates/status/891689557...                13
# 4  https://twitter.com/dog_rates/status/891327558...                12
#
#    rating_denominator  ...   img_num           p1   p1_conf  p1_dog  \
# 0                  10  ...       1.0       orange  0.097049   False
# 1                  10  ...       1.0    Chihuahua  0.323581    True
# 2                  10  ...       1.0    Chihuahua  0.716012    True
# 3                  10  ...       1.0  paper_towel  0.170278   False
# 4                  10  ...       2.0       basset  0.555712    True
#
#                    p2   p2_conf p2_dog                           p3   p3_conf  \
# 0               bagel  0.085851  False                       banana  0.076110
# 1            Pekinese  0.090647   True                     papillon  0.068957
# 2            malamute  0.078253   True                       kelpie  0.031379
# 3  Labrador_retriever  0.168086   True                      spatula  0.040836
# 4    English_springer  0.225770   True  German_short-haired_pointer  0.175219
#
#   p3_dog
# 0  False
# 1   True
# 2   True
# 3  False
# 4   True
#
# [5 rows x 25 columns]

# %%
df.columns
# Out:
# Index(['tweet_id', 'timestamp', 'source', 'text', 'retweeted_status_id',
#        'retweeted_status_user_id', 'retweeted_status_timestamp',
#        'expanded_urls', 'rating_numerator', 'rating_denominator', 'name',
#        'dog_stage', 'favorites', 'retweets', 'jpg_url', 'img_num', 'p1',
#        'p1_conf', 'p1_dog', 'p2', 'p2_conf', 'p2_dog', 'p3', 'p3_conf',
#        'p3_dog'],
#       dtype='object')

# %% [markdown]
# ***

# %% [markdown]
# ### Quality

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2356 entries, 0 to 2355
# Data columns (total 25 columns):
# tweet_id                      2356 non-null int64
# timestamp                     2356 non-null object
# source                        2356 non-null object
# text                          2356 non-null object
# retweeted_status_id           181 non-null float64
# retweeted_status_user_id      181 non-null float64
# retweeted_status_timestamp    181 non-null object
# expanded_urls                 2356 non-null object
# rating_numerator              2356 non-null int64
# rating_denominator            2356 non-null int64
# name                          2356 non-null object
# dog_stage                     2356 non-null object
# favorites                     2354 non-null float64
# retweets                      2354 non-null float64
# jpg_url                       2075 non-null object
# img_num                       2075 non-null float64
# p1                            2075 non-null object
# p1_conf                       2075 non-null float64
# p1_dog                        2075 non-null object
# p2                            2075 non-null object
# p2_conf                       2075 non-null float64
# p2_dog                        2075 non-null object
# p3                            2075 non-null object
# p3_conf                       2075 non-null float64
# p3_dog                        2075 non-null object
# dtypes: float64(8), int64(3), object(14)
# memory usage: 478.6+ KB

# %% [markdown]
# #### tweet_id should be string
# #### tiemstamp should be timestamp
# #### dog_stage could be categorical
# #### favorites should be integer without decimal
# #### retweets should be integer without decimal
# #### p1/p1_dog/p2/p2_dog/p3/p3_dog could be categorical

# %% [markdown]
# ##### Define
# Use astype to convert those data type

# %% [markdown]
# ##### Code

# %%
df[['dog_stage','p1','p1_dog','p2','p2_dog','p3','p3_dog']]=df[['dog_stage','p1','p1_dog','p2','p2_dog','p3','p3_dog']].astype('category')

# %%
df['tweet_id']=df['tweet_id'].astype(str)
df[['favorites','retweets']]=df[['favorites','retweets']].fillna(0.0).astype(int)

# %%
df['timestamp']=pd.to_datetime(df['timestamp'])

# %% [markdown]
# ##### Test

# %%
df.info()# re-check data type
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2356 entries, 0 to 2355
# Data columns (total 25 columns):
# tweet_id                      2356 non-null object
# timestamp                     2356 non-null datetime64[ns]
# source                        2356 non-null object
# text                          2356 non-null object
# retweeted_status_id           181 non-null float64
# retweeted_status_user_id      181 non-null float64
# retweeted_status_timestamp    181 non-null object
# expanded_urls                 2356 non-null object
# rating_numerator              2356 non-null int64
# rating_denominator            2356 non-null int64
# name                          2356 non-null object
# dog_stage                     2356 non-null category
# favorites                     2356 non-null int64
# retweets                      2356 non-null int64
# jpg_url                       2075 non-null object
# img_num                       2075 non-null float64
# p1                            2075 non-null category
# p1_conf                       2075 non-null float64
# p1_dog                        2075 non-null category
# p2                            2075 non-null category
# p2_conf                       2075 non-null float64
# p2_dog                        2075 non-null category
# p3                            2075 non-null category
# p3_conf                       2075 non-null float64
# p3_dog                        2075 non-null category
# dtypes: category(7), datetime64[ns](1), float64(6), int64(4), object(7)
# memory usage: 432.5+ KB

# %% [markdown]
# ***

# %%
df.rating_denominator.value_counts()
# I don't understand how this rating system works, however a denominator of 0 doesn't make sense
# Out:
# 10     2333
# 11        3
# 50        3
# 80        2
# 20        2
# 2         1
# 16        1
# 40        1
# 70        1
# 15        1
# 90        1
# 110       1
# 120       1
# 130       1
# 150       1
# 170       1
# 7         1
# 0         1
# Name: rating_denominator, dtype: int64

# %% [markdown]
# #### There is a 0 in the denominator column

# %% [markdown]
# ##### Define
# Remove theis row with 0 in denominator column

# %% [markdown]
# ##### Code

# %%
df.iloc[np.where(df.rating_denominator==0)]
# the numerator is pretty extreme too, I guess it wanted to show something like an infinite rating, 
# however, if I want to analyze it based on math, it won't work. So I'll drop this row
# Out:
#                tweet_id           timestamp  \
# 313  835246439529840640 2017-02-24 21:54:03
#
#                                                 source  \
# 313  <a href="http://twitter.com/download/iphone" r...
#
#                                                   text  retweeted_status_id  \
# 313  @jonnysun @Lin_Manuel ok jomny I know you're e...                  NaN
#
#      retweeted_status_user_id retweeted_status_timestamp  \
# 313                       NaN                        NaN
#
#                                          expanded_urls  rating_numerator  \
# 313  https://twitter.com/dog_rates/status/835246439...               960
#
#      rating_denominator  ...   img_num   p1  p1_conf  p1_dog   p2  p2_conf  \
# 313                   0  ...       NaN  NaN      NaN     NaN  NaN      NaN
#
#     p2_dog   p3 p3_conf p3_dog
# 313    NaN  NaN     NaN    NaN
#
# [1 rows x 25 columns]

# %%
df.drop(index=np.where(df.rating_denominator==0)[0],inplace=True)

# %% [markdown]
# ##### Test

# %%
df.shape
# Out:
# (2355, 25)

# %% [markdown]
# ***

# %% [markdown]
# #### Retweets are not needed

# %% [markdown]
# ##### Define
# Preserve only rows that have NaN in "retweeted_status_id","retweeted_status_user_id","retweeted_status_timestamp" columns

# %% [markdown]
# ##### Code

# %%
# retweets are not wanted, so I'll remove them
# make sure all the rows with NaN in "retweeted_status_id",
# "retweeted_status_user_id", and "retweeted_status_timestamp" are the same
np.all(df[~df.retweeted_status_id.isnull()].index)==np.all(df[~df.retweeted_status_user_id.isnull()].index)
# Out:
# True

# %%
np.all(df[~df.retweeted_status_id.isnull()].index)==np.all(df[~df.retweeted_status_timestamp.isnull()].index)
# it looks like rows with values in "retweeted_status_id","retweeted_status_user_id","df.retweeted_status_timestamp"
# represent retweet instead of original ones, so I'll drop them
# Out:
# True

# %%
retweet_index=df[~df.retweeted_status_id.isnull()].index
df.drop(index=retweet_index,inplace=True)

# %%
df.shape
# Out:
# (2174, 25)

# %%
df.retweeted_status_id.isnull().sum(),df.retweeted_status_user_id.isnull().sum(),df.retweeted_status_timestamp.isnull().sum()
# now that all variables in these three columns are NaN, I'll drop all these columns
# Out:
# (2174, 2174, 2174)

# %%
df.drop(columns=['retweeted_status_id', 'retweeted_status_user_id','retweeted_status_timestamp'],inplace=True)

# %% [markdown]
# ##### Test

# %%
df.shape
# Out:
# (2174, 22)

# %% [markdown]
# ***

# %% [markdown]
# #### Text start with "RT" are also retweets

# %% [markdown]
# ##### Define
# Remove rows begin with "RT" in the text column

# %% [markdown]
# ##### Code

# %%
df[df.text.str.contains(pat='^RT.+')]['text']
# there are two rows with text columns start with RT, they are probably retweet, so remove them as well
# Out:
# 1286    RT if you are as ready for summer as this pup ...
# 1860    RT until we find this dog. Clearly a cool dog ...
# Name: text, dtype: object

# %%
RT_index=df[df.text.str.contains(pat='^RT.+')].index
df.drop(index=RT_index,inplace=True)

# %% [markdown]
# ##### Test

# %%
df[df.text.str.contains(pat='^RT.+')]['text']
# Out:
# Series([], Name: text, dtype: object)

# %% [markdown]
# ***

# %%
df.name.value_counts()
# Out:
# None        677
# a            55
# Lucy         11
# Charlie      11
# Cooper       10
# Oliver       10
# Tucker        9
# Penny         9
# the           8
# Sadie         8
# Winston       8
# Lola          8
# Toby          7
# Daisy         7
# an            6
# Oscar         6
# Jax           6
# Bella         6
# Koda          6
# Stanley       6
# Bo            6
# Bailey        6
# Buddy         5
# Rusty         5
# Milo          5
# Leo           5
# Louis         5
# Scout         5
# Dave          5
# Chester       5
#            ...
# Brownie       1
# Gustaf        1
# Jockson       1
# Spanky        1
# Butter        1
# Toffee        1
# Rover         1
# Huck          1
# Kellogg       1
# Tilly         1
# Raphael       1
# Willie        1
# Amber         1
# Kona          1
# Chubbs        1
# Sweet         1
# Zara          1
# Darla         1
# Harrison      1
# Jarod         1
# Zeus          1
# Chesney       1
# Hall          1
# Tonks         1
# Timmy         1
# Todo          1
# Griswold      1
# Davey         1
# Aubie         1
# Jazzy         1
# Name: name, Length: 956, dtype: int64

# %% [markdown]
# #### "a" in name column

# %% [markdown]
# ##### Define
# Replace "a" with "None"

# %% [markdown]
# ##### Code

# %%
df[df.name=='a'].iloc[0]['text']
# Out:
# 'Here is a pupper approaching maximum borkdrive. Zooming at never before seen speeds. 14/10 paw-inspiring af \n(IG: puffie_the_chow)'

# %%
df[df.name=='a'].iloc[1]['text']
# it looks like rows with "a" in the name column is simply 
# because names were not provided, I'll chage them to 'None'
# Out:
# 'Here is a perfect example of someone who has their priorities in order. 13/10 for both owner and Forrest'

# %%
df['name']=df['name'].str.replace('^a','None')

# %% [markdown]
# ##### Test

# %%
df.name.value_counts()
#677+55=732, all the "a" have become None
#this column actually have some other "names" that do not look like names, but I am not planning to analyze dog names, 
# I'll just leave them as they are.
# Out:
# None            732
# Lucy             11
# Charlie          11
# Cooper           10
# Oliver           10
# Penny             9
# Tucker            9
# Lola              8
# Winston           8
# Sadie             8
# the               8
# Daisy             7
# Toby              7
# Stanley           6
# Nonen             6
# Oscar             6
# Jax               6
# Koda              6
# Bella             6
# Bo                6
# Bailey            6
# Bentley           5
# Louis             5
# Buddy             5
# Chester           5
# Rusty             5
# Dave              5
# Milo              5
# Scout             5
# Leo               5
#                ...
# Brownie           1
# Gustaf            1
# Jockson           1
# Spanky            1
# Toffee            1
# Rover             1
# Huck              1
# Aubie             1
# Cleopatricia      1
# Kellogg           1
# Tilly             1
# Raphael           1
# Willie            1
# Amber             1
# Kona              1
# Chubbs            1
# Sweet             1
# Zara              1
# Darla             1
# Harrison          1
# Jarod             1
# Zeus              1
# Chesney           1
# Hall              1
# Tonks             1
# Timmy             1
# Todo              1
# Griswold          1
# Davey             1
# Jazzy             1
# Name: name, Length: 955, dtype: int64

# %% [markdown]
# ***

# %% [markdown]
# #### Source column doesn't seem to provide any useful information for analysis

# %% [markdown]
# ##### Define
# Drop source column

# %% [markdown]
# ##### Code

# %%
df.drop(labels='source',axis=1, inplace=True)

# %% [markdown]
# ##### Test

# %%
df.shape
# Out:
# (2172, 21)

# %% [markdown]
# ***

# %%
df.columns
# Out:
# Index(['tweet_id', 'timestamp', 'text', 'expanded_urls', 'rating_numerator',
#        'rating_denominator', 'name', 'dog_stage', 'favorites', 'retweets',
#        'jpg_url', 'img_num', 'p1', 'p1_conf', 'p1_dog', 'p2', 'p2_conf',
#        'p2_dog', 'p3', 'p3_conf', 'p3_dog'],
#       dtype='object')

# %%
df.loc[2355,'expanded_urls']
# Out:
# 'https://twitter.com/dog_rates/status/666020888022790149/photo/1'

# %%
df.loc[2355,'jpg_url']
# expended_url direct to twitter site and jpg_url to a jpg photo, however, the two photos are basically the same.
# jpg_url is probably a backup for expanded_url.
# Out:
# 'https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg'

# %%
df[~df['expanded_urls'].str.contains(pat='https://twitter.com/')]
# some expanded_urls do not direct to twitter site
# Out:
#                 tweet_id           timestamp  \
# 335   832645525019123713 2017-02-17 17:38:57
# 444   819238181065359361 2017-01-11 17:42:57
# 529   808344865868283904 2016-12-12 16:16:49
# 562   802600418706604034 2016-11-26 19:50:26
# 657   791774931465953280 2016-10-27 22:53:48
# 672   789903600034189313 2016-10-22 18:57:48
# 699   786286427768250368 2016-10-12 19:24:27
# 713   784183165795655680 2016-10-07 00:06:50
# 714   784057939640352768 2016-10-06 15:49:14
# 731   781655249211752448 2016-09-30 00:41:48
# 733   781308096455073793 2016-09-29 01:42:20
# 746   780074436359819264 2016-09-25 16:00:13
# 754   778764940568104960 2016-09-22 01:16:45
# 783   775350846108426240 2016-09-12 15:10:21
# 881   760521673607086080 2016-08-02 17:04:31
# 886   759943073749200896 2016-08-01 02:45:22
# 905   758099635764359168 2016-07-27 00:40:12
# 939   753039830821511168 2016-07-13 01:34:21
# 941   752932432744185856 2016-07-12 18:27:35
# 946   752568224206688256 2016-07-11 18:20:21
# 951   751950017322246144 2016-07-10 01:23:49
# 954   751793661361422336 2016-07-09 15:02:31
# 985   749075273010798592 2016-07-02 03:00:36
# 996   748337862848962560 2016-06-30 02:10:24
# 999   748220828303695873 2016-06-29 18:25:21
# 1006  747648653817413632 2016-06-28 04:31:44
# 1011  747439450712596480 2016-06-27 14:40:26
# 1020  746757706116112384 2016-06-25 17:31:25
# 1022  746542875601690625 2016-06-25 03:17:46
# 1033  745074613265149952 2016-06-21 02:03:25
# ...                  ...                 ...
# 1482  693267061318012928 2016-01-30 02:58:42
# 1502  692041934689402880 2016-01-26 17:50:29
# 1505  691793053716221953 2016-01-26 01:21:31
# 1515  690989312272396288 2016-01-23 20:07:44
# 1528  690348396616552449 2016-01-22 01:40:58
# 1534  689993469801164801 2016-01-21 02:10:37
# 1549  689255633275777024 2016-01-19 01:18:43
# 1566  687841446767013888 2016-01-15 03:39:15
# 1570  687732144991551489 2016-01-14 20:24:55
# 1577  687399393394311168 2016-01-13 22:22:41
# 1586  686760001961103360 2016-01-12 04:01:58
# 1592  686394059078897668 2016-01-11 03:47:50
# 1596  686286779679375361 2016-01-10 20:41:33
# 1625  684830982659280897 2016-01-06 20:16:44
# 1628  684588130326986752 2016-01-06 04:11:43
# 1640  684147889187209216 2016-01-04 23:02:22
# 1650  683515932363329536 2016-01-03 05:11:12
# 1676  682088079302213632 2015-12-30 06:37:25
# 1706  680805554198020098 2015-12-26 17:41:07
# 1728  679872969355714560 2015-12-24 03:55:21
# 1743  679405845277462528 2015-12-22 20:59:10
# 1750  679001094530465792 2015-12-21 18:10:50
# 1760  678708137298427904 2015-12-20 22:46:44
# 1776  677961670166224897 2015-12-18 21:20:32
# 1791  677335745548390400 2015-12-17 03:53:20
# 1807  676916996760600576 2015-12-16 00:09:23
# 1818  676593408224403456 2015-12-15 02:43:33
# 1834  676121918416756736 2015-12-13 19:30:01
# 1916  674307341513269249 2015-12-08 19:19:32
# 2212  668587383441514497 2015-11-23 00:30:28
#
#                                                    text  \
# 335   There's going to be a dog terminal at JFK Airp...
# 444   Some happy pupper news to share. 10/10 for eve...
# 529   This is Seamus. He's very bad at entering pool...
# 562   This is Bailey. She has mastered the head tilt...
# 657   Vine will be deeply missed. This was by far my...
# 672   This is Ralphy. His dreams were just shattered...
# 699   This is Arnie. He's afraid of his own bark. 12...
# 713   This is Reginald. He's one magical puppo. Aero...
# 714   This is Balto. He's very content. Legendary to...
# 731   This is Combo. The daily struggles of being a ...
# 733                  Pupper butt 1, Doggo 0. Both 12/10
# 746   Here's a doggo questioning his entire existenc...
# 754   Oh my god it's Narcos but Barkos. 13/10 someon...
# 783   This is Maximus. A little rain won't stop him....
# 881   Doggo want what doggo cannot have. Temptation ...
# 886   Here's a wicked fast pupper. 12/10 camera coul...
# 905   In case you haven't seen the most dramatic sne...
# 939    So this just changed my life. 13/10 please enjoy
# 941   This is Carl. He's very powerful. 12/10 don't ...
# 946   Here are three doggos completely misjudging an...
# 951   This is Lola. She's a surfing pupper. 13/10 ma...
# 954   This is Fred. He's having one heck of a summer...
# 985   This is Boomer. He's self-baptizing. Other dog...
# 996          SWIM AWAY PUPPER SWIM AWAY 13/10 #BarkWeek
# 999   Stop what you're doing and watch this heckin m...
# 1006  This is Keurig. He apparently headbutts other ...
# 1011  This is Linus. He just wanted to say hello but...
# 1020  This is Maddie. She gets some wicked air time....
# 1022  Here's a golden floofer helping with the groce...
# 1033  This is Jeffrey. He wasn't prepared to execute...
# ...                                                 ...
# 1482  This is Oscar. He can wave. Friendly af. 12/10...
# 1502  This is Teddy. His head is too heavy. 13/10 (v...
# 1505  We usually don't rate penguins but this one is...
# 1515  We've got a doggy down. Requesting backup. 12/...
# 1528  This is Oddie. He's trying to communicate. 12/...
# 1534  Here we are witnessing a rare High Stepping Al...
# 1549  This is Ferg. He swallowed a chainsaw. 1 like ...
# 1566  13/10 I can't stop watching this (vid by @k8ly...
# 1570  This is Ember. That's the q-tip she owes money...
# 1577  This is Barry. He's very fast. I hope he finds...
# 1586  This pupper forgot how to walk. 12/10 happens ...
# 1592  This pup's having a nightmare that he forgot t...
# 1596  When bae calls your name from across the room....
# 1625  This little fella really hates stairs. Prefers...
# 1628  This pupper just got his first kiss. 12/10 he'...
# 1640  This is Sweets the English Bulldog. Waves back...
# 1650  HEY PUP WHAT'S THE PART OF THE HUMAN BODY THAT...
# 1676  I'm not sure what this dog is doing but it's p...
# 1706  This guy's dog broke. So sad. 9/10 would still...
# 1728  This is Rocco. He's in a very intense game of ...
# 1743  Crazy unseen footage from Jurassic Park. 10/10...
# 1750  This is Rascal. He's paddling an imaginary can...
# 1760  Here we are witnessing a wild field pupper. Lo...
# 1776  This is Izzy. She's showing off the dance move...
# 1791                          Downright inspiring 12/10
# 1807  Super speedy pupper. Does not go gentle into t...
# 1818  This pupper loves leaves. 11/10 for committed ...
# 1834  Here we are witnessing a very excited dog. Cle...
# 1916                       This is life-changing. 12/10
# 2212  Never forget this vine. You will not stop watc...
#
#                                           expanded_urls  rating_numerator  \
# 335   http://us.blastingnews.com/news/2017/02/jfk-an...                10
# 444   http://us.blastingnews.com/news/2017/01/200-do...                10
# 529                       https://vine.co/v/5QWd3LZqXxd                11
# 562                       https://vine.co/v/5FwUWjYaW0Y                11
# 657                       https://vine.co/v/ea0OwvPTx9l                14
# 672                       https://vine.co/v/5wPT1aBxPQZ                13
# 699                       https://vine.co/v/5XH0WqHwiFp                12
# 713                       https://vine.co/v/5ghHLBMMdlV                12
# 714                       https://vine.co/v/5gKxeUpuKEr                12
# 731                       https://vine.co/v/5rt6T3qm7hL                11
# 733                       https://vine.co/v/5rgu2Law2ut                12
# 746                       https://vine.co/v/5nzYBpl0TY2                10
# 754   https://m.youtube.com/watch?v=idKxCMsS3FQ&feat...                13
# 783                       https://vine.co/v/ijmv0PD0XXD                12
# 881                       https://vine.co/v/5ApKetxzmTB                12
# 886                       https://vine.co/v/5AJm5pq7Kav                12
# 905                       https://vine.co/v/hQJbaj1VpIz                13
# 939                       https://vine.co/v/5W2Dg3XPX7a                13
# 941                       https://vine.co/v/OEppMFbejFz                12
# 946                       https://vine.co/v/5W0bdhEUUVT                 9
# 951                       https://vine.co/v/5WrjaYAMvMO                13
# 954                       https://vine.co/v/5W5YHdTJvaV                11
# 985                       https://vine.co/v/5ztZvHgI17r                11
# 996                       https://vine.co/v/h5aDaFthX6O                13
# 999                       https://vine.co/v/iiLjKuYJpr6                13
# 1006                      https://vine.co/v/iqIZFtOxEMB                12
# 1011                      https://vine.co/v/5uTVXWvn3Ip                12
# 1020                      https://vine.co/v/5BYq6hmrEI3                11
# 1022                      https://vine.co/v/5uZYwqmuDeT                11
# 1033                      https://vine.co/v/iQm3JAXuFmv                11
# ...                                                 ...               ...
# 1482                      https://vine.co/v/i5n2irFUYWv                12
# 1502                      https://vine.co/v/iiI3wmqXYmA                13
# 1505                      https://vine.co/v/OTTVAKw6YlW                10
# 1515                      https://vine.co/v/iOZKZEU2nHq                12
# 1528                      https://vine.co/v/iejBWerY9X2                12
# 1534                      https://vine.co/v/ienexVMZgi5                12
# 1549                      https://vine.co/v/iOL792n5hz2                10
# 1566                      https://vine.co/v/iOWwUPH1hrw                13
# 1570                      https://vine.co/v/iOuMphL5DBY                11
# 1577                      https://vine.co/v/iM2hLu9LU5i                10
# 1586                      https://vine.co/v/iMvubwT260D                12
# 1592                      https://vine.co/v/iMqBebnOvav                12
# 1596                      https://vine.co/v/iMZx6aDbExn                12
# 1625                      https://vine.co/v/eEZXZI1rqxX                13
# 1628                      https://vine.co/v/ihWIxntjtO7                12
# 1640                      https://vine.co/v/ib2nTOEuuOI                12
# 1650                      https://vine.co/v/ibvnzrauFuV                11
# 1676                      https://vine.co/v/iqMjlxULzbn                12
# 1706                      https://vine.co/v/iAP0Ugzi2PO                 9
# 1728                      https://vine.co/v/iAAxTbj1UAM                10
# 1743                      https://vine.co/v/iKVFEigMLxP                10
# 1750                      https://vine.co/v/iKIwAzEatd6                11
# 1760                      https://vine.co/v/eQjxxYaQ60K                10
# 1776                      https://vine.co/v/iKuMDuYV0aZ                11
# 1791                      https://vine.co/v/hbLbH77Ar67                12
# 1807                      https://vine.co/v/imJ0BdZOJTw                10
# 1818                      https://vine.co/v/eEQQaPFbgOY                11
# 1834                      https://vine.co/v/iZXg7VpeDAv                 8
# 1916                      https://vine.co/v/i7nWzrenw5h                12
# 2212                      https://vine.co/v/ea0OwvPTx9l                13
#
#       rating_denominator      name   dog_stage  favorites  retweets   ...    \
# 335                   10       not        None       3195       594   ...
# 444                   10      None      pupper       2550       462   ...
# 529                   10    Seamus        None      47281     24069   ...
# 562                   10    Bailey        None       7938      1714   ...
# 657                   10      None        None      37818     21156   ...
# 672                   10    Ralphy      pupper      11673      4858   ...
# 699                   10     Arnie        None       8930      3352   ...
# 713                   10  Reginald       puppo      22513      9374   ...
# 714                   10     Balto        None      33505     12953   ...
# 731                   10     Combo       doggo       4466      1314   ...
# 733                   10      None  duplicated       7973      2961   ...
# 746                   10      None       doggo      13723      5815   ...
# 754                   10      None        None        955       426   ...
# 783                   10   Maximus        None      11309      4532   ...
# 881                   10      None       doggo       4681      1608   ...
# 886                   10      None      pupper       6581      2382   ...
# 905                   10      None        None      21302     11550   ...
# 939                   10      None        None      41080     24013   ...
# 941                   10      Carl        None      13970      7798   ...
# 946                   10      None        None       6140      2605   ...
# 951                   10      Lola      pupper       3415      1060   ...
# 954                   10      Fred        None       6479      3320   ...
# 985                   10    Boomer       doggo       6353      2360   ...
# 996                   10      None      pupper       8462      4701   ...
# 999                   10      None        None      15549      8825   ...
# 1006                  10    Keurig        None      14182      6614   ...
# 1011                  10     Linus        None       5965      2184   ...
# 1020                  10    Maddie        None      10520      4432   ...
# 1022                  10      None     floofer       5520      2104   ...
# 1033                  10   Jeffrey        None       8605      3976   ...
# ...                  ...       ...         ...        ...       ...   ...
# 1482                  10     Oscar        None       2622       925   ...
# 1502                  10     Teddy        None       3724      1424   ...
# 1505                  10      None        None       8910      4732   ...
# 1515                  10      None        None       6513      3282   ...
# 1528                  10     Oddie        None       1644       573   ...
# 1534                  10      None     floofer       1618       518   ...
# 1549                  10      Ferg        None       2805      1212   ...
# 1566                  10      None        None       6009      2872   ...
# 1570                  10     Ember        None       1935       750   ...
# 1577                  10     Barry        None       2081       702   ...
# 1586                  10      None      pupper       3852      1551   ...
# 1592                  10      None        None       1928       769   ...
# 1596                  10      None        None       4392      1887   ...
# 1625                  10      None      pupper      38551     24514   ...
# 1628                  10      None      pupper       4489      1592   ...
# 1640                  10    Sweets      pupper       3265      1703   ...
# 1650                  10      None        None       8058      3291   ...
# 1676                  10      None        None      20108     11271   ...
# 1706                  10      None        None       2370       751   ...
# 1728                  10     Rocco        None       2365       749   ...
# 1743                  10      None        None       2594      1364   ...
# 1750                  10    Rascal        None       3075      1378   ...
# 1760                  10      None      pupper       6082      2753   ...
# 1776                  10      Izzy        None       3701      1879   ...
# 1791                  10      None        None       3328      2017   ...
# 1807                  10      None      pupper       3231      2002   ...
# 1818                  10      None      pupper       4954      2410   ...
# 1834                  10      None        None       2335      1297   ...
# 1916                  10      life        None      12129      7641   ...
# 2212                  10       the        None       1760      1174   ...
#
#      img_num   p1 p1_conf  p1_dog   p2 p2_conf  p2_dog   p3 p3_conf  p3_dog
# 335      NaN  NaN     NaN     NaN  NaN     NaN     NaN  NaN     NaN     NaN
# 444      NaN  NaN     NaN     NaN  NaN     NaN     NaN  NaN     NaN     NaN
# 529      NaN  NaN     NaN     NaN  NaN     NaN     NaN  NaN     NaN     NaN
# 562      NaN  NaN     NaN     NaN  NaN     NaN     NaN  NaN     NaN     NaN
# 657      NaN  NaN     NaN     NaN  NaN     NaN     NaN  NaN     NaN     NaN
# 672      NaN  NaN     NaN     NaN  NaN     NaN     NaN  NaN     NaN     NaN
# 699      NaN  NaN     NaN     NaN  NaN     NaN     NaN  NaN     NaN     NaN
# 713      NaN  NaN     NaN     NaN  NaN     NaN     NaN  NaN     NaN     NaN
# 714      NaN  NaN     NaN     NaN  NaN     NaN     NaN  NaN     NaN     NaN
# 731      NaN  NaN     NaN     NaN  NaN     NaN     NaN  NaN     NaN     NaN
# 733      NaN  NaN     NaN     NaN  NaN     NaN     NaN  NaN     NaN     NaN
# 746      NaN  NaN     NaN     NaN  NaN     NaN     NaN  NaN     NaN     NaN
# 754      NaN  NaN     NaN     NaN  NaN     NaN     NaN  NaN     NaN     NaN
# 783      NaN  NaN     NaN     NaN  NaN     NaN     NaN  NaN     NaN     NaN
# 881      NaN  NaN     NaN     NaN  NaN     NaN     NaN  NaN     NaN     NaN
# 886      NaN  NaN     NaN     NaN  NaN     NaN     NaN  NaN     NaN     NaN
# 905      NaN  NaN     NaN     NaN  NaN     NaN     NaN  NaN     NaN     NaN
# 939      NaN  NaN     NaN     NaN  NaN     NaN     NaN  NaN     NaN     NaN
# 941      NaN  NaN     NaN     NaN  NaN     NaN     NaN  NaN     NaN     NaN
# 946      NaN  NaN     NaN     NaN  NaN     NaN     NaN  NaN     NaN     NaN
# 951      NaN  NaN     NaN     NaN  NaN     NaN     NaN  NaN     NaN     NaN
# 954      NaN  NaN     NaN     NaN  NaN     NaN     NaN  NaN     NaN     NaN
# 985      NaN  NaN     NaN     NaN  NaN     NaN     NaN  NaN     NaN     NaN
# 996      NaN  NaN     NaN     NaN  NaN     NaN     NaN  NaN     NaN     NaN
# 999      NaN  NaN     NaN     NaN  NaN     NaN     NaN  NaN     NaN     NaN
# 1006     NaN  NaN     NaN     NaN  NaN     NaN     NaN  NaN     NaN     NaN
# 1011     NaN  NaN     NaN     NaN  NaN     NaN     NaN  NaN     NaN     NaN
# 1020     NaN  NaN     NaN     NaN  NaN     NaN     NaN  NaN     NaN     NaN
# 1022     NaN  NaN     NaN     NaN  NaN     NaN     NaN  NaN     NaN     NaN
# 1033     NaN  NaN     NaN     NaN  NaN     NaN     NaN  NaN     NaN     NaN
# ...      ...  ...     ...     ...  ...     ...     ...  ...     ...     ...
# 1482     NaN  NaN     NaN     NaN  NaN     NaN     NaN  NaN     NaN     NaN
# 1502     NaN  NaN     NaN     NaN  NaN     NaN     NaN  NaN     NaN     NaN
# 1505     NaN  NaN     NaN     NaN  NaN     NaN     NaN  NaN     NaN     NaN
# 1515     NaN  NaN     NaN     NaN  NaN     NaN     NaN  NaN     NaN     NaN
# 1528     NaN  NaN     NaN     NaN  NaN     NaN     NaN  NaN     NaN     NaN
# 1534     NaN  NaN     NaN     NaN  NaN     NaN     NaN  NaN     NaN     NaN
# 1549     NaN  NaN     NaN     NaN  NaN     NaN     NaN  NaN     NaN     NaN
# 1566     NaN  NaN     NaN     NaN  NaN     NaN     NaN  NaN     NaN     NaN
# 1570     NaN  NaN     NaN     NaN  NaN     NaN     NaN  NaN     NaN     NaN
# 1577     NaN  NaN     NaN     NaN  NaN     NaN     NaN  NaN     NaN     NaN
# 1586     NaN  NaN     NaN     NaN  NaN     NaN     NaN  NaN     NaN     NaN
# 1592     NaN  NaN     NaN     NaN  NaN     NaN     NaN  NaN     NaN     NaN
# 1596     NaN  NaN     NaN     NaN  NaN     NaN     NaN  NaN     NaN     NaN
# 1625     NaN  NaN     NaN     NaN  NaN     NaN     NaN  NaN     NaN     NaN
# 1628     NaN  NaN     NaN     NaN  NaN     NaN     NaN  NaN     NaN     NaN
# 1640     NaN  NaN     NaN     NaN  NaN     NaN     NaN  NaN     NaN     NaN
# 1650     NaN  NaN     NaN     NaN  NaN     NaN     NaN  NaN     NaN     NaN
# 1676     NaN  NaN     NaN     NaN  NaN     NaN     NaN  NaN     NaN     NaN
# 1706     NaN  NaN     NaN     NaN  NaN     NaN     NaN  NaN     NaN     NaN
# 1728     NaN  NaN     NaN     NaN  NaN     NaN     NaN  NaN     NaN     NaN
# 1743     NaN  NaN     NaN     NaN  NaN     NaN     NaN  NaN     NaN     NaN
# 1750     NaN  NaN     NaN     NaN  NaN     NaN     NaN  NaN     NaN     NaN
# 1760     NaN  NaN     NaN     NaN  NaN     NaN     NaN  NaN     NaN     NaN
# 1776     NaN  NaN     NaN     NaN  NaN     NaN     NaN  NaN     NaN     NaN
# 1791     NaN  NaN     NaN     NaN  NaN     NaN     NaN  NaN     NaN     NaN
# 1807     NaN  NaN     NaN     NaN  NaN     NaN     NaN  NaN     NaN     NaN
# 1818     NaN  NaN     NaN     NaN  NaN     NaN     NaN  NaN     NaN     NaN
# 1834     NaN  NaN     NaN     NaN  NaN     NaN     NaN  NaN     NaN     NaN
# 1916     NaN  NaN     NaN     NaN  NaN     NaN     NaN  NaN     NaN     NaN
# 2212     NaN  NaN     NaN     NaN  NaN     NaN     NaN  NaN     NaN     NaN
#
# [93 rows x 21 columns]

# %%
urls=df[~df.expanded_urls.str.contains(pat='https://twitter.com/')][['expanded_urls','jpg_url']].copy()

# %%
urls.isnull().sum()
# in those rows with non-twitter expanded_urls, none of them has jpg_url.
# I can say that this column is coupled with twitter site with photo or NaN when expanded_urls are not twitter site
# I'll discard this column since it is a duplicate url column
# Out:
# expanded_urls     0
# jpg_url          93
# dtype: int64

# %% [markdown]
# #### jpg_url has photo that's a duplicate to expanded_urls

# %% [markdown]
# ##### Define
# Remove jpg_url column

# %% [markdown]
# ##### Code

# %%
df.drop(labels='jpg_url',axis=1, inplace=True)

# %% [markdown]
# ##### Test

# %%
df.shape
# Out:
# (2172, 20)

# %% [markdown]
# ***

# %%
df[df.duplicated(subset='expanded_urls',keep=False)]
# these two posts referred to the same dog, I'll drop one of them.
# Out:
#                 tweet_id           timestamp  \
# 657   791774931465953280 2016-10-27 22:53:48
# 2212  668587383441514497 2015-11-23 00:30:28
#
#                                                    text  \
# 657   Vine will be deeply missed. This was by far my...
# 2212  Never forget this vine. You will not stop watc...
#
#                       expanded_urls  rating_numerator  rating_denominator  \
# 657   https://vine.co/v/ea0OwvPTx9l                14                  10
# 2212  https://vine.co/v/ea0OwvPTx9l                13                  10
#
#       name dog_stage  favorites  retweets  img_num   p1  p1_conf p1_dog   p2  \
# 657   None      None      37818     21156      NaN  NaN      NaN    NaN  NaN
# 2212   the      None       1760      1174      NaN  NaN      NaN    NaN  NaN
#
#       p2_conf p2_dog   p3  p3_conf p3_dog
# 657       NaN    NaN  NaN      NaN    NaN
# 2212      NaN    NaN  NaN      NaN    NaN

# %% [markdown]
# #### 657 and 2212 has the same dog photo and name

# %% [markdown]
# ##### Define
# Drop one of these two rows

# %% [markdown]
# ##### Code

# %%
df.drop(index=657,axis=0, inplace=True)

# %% [markdown]
# ##### Test

# %%
df.shape
# Out:
# (2171, 20)

# %% [markdown]
# ***

# %% [markdown]
# #### I tried to find if the rating in the text column matches rating_denominator and rating_numerator columns. It turned out that they are all correct. So I did not do any changes here. Below are what I did

# %%
numerator_denominator = df.text.str.extract(r'(\d{1,4})\/(\d{1,4})',expand=True)

# %%
rating = df[['rating_denominator','rating_numerator','text']].copy()
rating = pd.concat([rating,numerator_denominator], axis=1)
rating.rename(columns={0:'numerator',1:'denominator'},inplace=True)
rating
# Out:
#       rating_denominator  rating_numerator  \
# 0                     10                13
# 1                     10                13
# 2                     10                12
# 3                     10                13
# 4                     10                12
# 5                     10                13
# 6                     10                13
# 7                     10                13
# 8                     10                13
# 9                     10                14
# 10                    10                13
# 11                    10                13
# 12                    10                13
# 13                    10                12
# 14                    10                13
# 15                    10                13
# 16                    10                12
# 17                    10                13
# 18                    10                13
# 20                    10                12
# 21                    10                13
# 22                    10                14
# 23                    10                13
# 24                    10                13
# 25                    10                12
# 26                    10                13
# 27                    10                13
# 28                    10                13
# 29                    10                12
# 30                    10                12
# ...                  ...               ...
# 2326                  10                 2
# 2327                  10                 7
# 2328                  10                 9
# 2329                  10                11
# 2330                  10                 6
# 2331                  10                 8
# 2332                  10                10
# 2333                  10                 9
# 2334                  10                 3
# 2335                   2                 1
# 2336                  10                11
# 2337                  10                10
# 2338                  10                 1
# 2339                  10                11
# 2340                  10                 8
# 2341                  10                 9
# 2342                  10                 6
# 2343                  10                10
# 2344                  10                 9
# 2345                  10                10
# 2346                  10                 8
# 2347                  10                 9
# 2348                  10                10
# 2349                  10                 2
# 2350                  10                10
# 2351                  10                 5
# 2352                  10                 6
# 2353                  10                 9
# 2354                  10                 7
# 2355                  10                 8
#
#                                                    text numerator denominator
# 0     This is Phineas. He's a mystical boy. Only eve...        13          10
# 1     This is Tilly. She's just checking pup on you....        13          10
# 2     This is Archie. He is a rare Norwegian Pouncin...        12          10
# 3     This is Darla. She commenced a snooze mid meal...        13          10
# 4     This is Franklin. He would like you to stop ca...        12          10
# 5     Here we have a majestic great white breaching ...        13          10
# 6     Meet Jax. He enjoys ice cream so much he gets ...        13          10
# 7     When you watch your owner call another dog a g...        13          10
# 8     This is Zoey. She doesn't want to be one of th...        13          10
# 9     This is Cassie. She is a college pup. Studying...        14          10
# 10    This is Koda. He is a South Australian decksha...        13          10
# 11    This is Bruno. He is a service shark. Only get...        13          10
# 12    Here's a puppo that seems to be on the fence a...        13          10
# 13    This is Ted. He does his best. Sometimes that'...        12          10
# 14    This is Stuart. He's sporting his favorite fan...        13          10
# 15    This is Oliver. You're witnessing one of his m...        13          10
# 16    This is Jim. He found a fren. Taught him how t...        12          10
# 17    This is Zeke. He has a new stick. Very proud o...        13          10
# 18    This is Ralphus. He's powering up. Attempting ...        13          10
# 20    This is Gerald. He was just told he didn't get...        12          10
# 21    This is Jeffrey. He has a monopoly on the pool...        13          10
# 22    I've yet to rate a Venezuelan Hover Wiener. Th...        14          10
# 23    This is Canela. She attempted some fancy porch...        13          10
# 24    You may not have known you needed to see this ...        13          10
# 25    This... is a Jubilant Antarctic House Bear. We...        12          10
# 26    This is Maya. She's very shy. Rarely leaves he...        13          10
# 27    This is Mingus. He's a wonderful father to his...        13          10
# 28    This is Derek. He's late for a dog meeting. 13...        13          10
# 29    This is Roscoe. Another pupper fallen victim t...        12          10
# 30    @NonWhiteHat @MayhewMayhem omg hello tanner yo...        12          10
# ...                                                 ...       ...         ...
# 2326  This is quite the dog. Gets really excited whe...         2          10
# 2327  This is a southern Vesuvius bumblegruff. Can d...         7          10
# 2328  Oh goodness. A super rare northeast Qdoba kang...         9          10
# 2329  Those are sunglasses and a jean jacket. 11/10 ...        11          10
# 2330  Unique dog here. Very small. Lives in containe...         6          10
# 2331  Here we have a mixed Asiago from the Galápagos...         8          10
# 2332  Look at this jokester thinking seat belt laws ...        10          10
# 2333  This is an extremely rare horned Parthenon. No...         9          10
# 2334  This is a funny dog. Weird toes. Won't come do...         3          10
# 2335  This is an Albanian 3 1/2 legged  Episcopalian...         1           2
# 2336                             Can take selfies 11/10        11          10
# 2337  Very concerned about fellow dog trapped in com...        10          10
# 2338  Not familiar with this breed. No tail (weird)....         1          10
# 2339  Oh my. Here you are seeing an Adobe Setter giv...        11          10
# 2340  Can stand on stump for what seems like a while...         8          10
# 2341  This appears to be a Mongolian Presbyterian mi...         9          10
# 2342  Here we have a well-established sunblockerspan...         6          10
# 2343  Let's hope this flight isn't Malaysian (lol). ...        10          10
# 2344  Here we have a northern speckled Rhododendron....         9          10
# 2345  This is the happiest dog you will ever see. Ve...        10          10
# 2346  Here is the Rand Paul of retrievers folks! He'...         8          10
# 2347  My oh my. This is a rare blond Canadian terrie...         9          10
# 2348  Here is a Siberian heavily armored polar bear ...        10          10
# 2349  This is an odd dog. Hard on the outside but lo...         2          10
# 2350  This is a truly beautiful English Wilson Staff...        10          10
# 2351  Here we have a 1949 1st generation vulpix. Enj...         5          10
# 2352  This is a purebred Piers Morgan. Loves to Netf...         6          10
# 2353  Here is a very happy pup. Big fan of well-main...         9          10
# 2354  This is a western brown Mitsubishi terrier. Up...         7          10
# 2355  Here we have a Japanese Irish Setter. Lost eye...         8          10
#
# [2171 rows x 5 columns]

# %%
rating.denominator.isnull().sum()
# Out:
# 17

# %%
rating.numerator.isnull().sum()
# Out:
# 17

# %%
np.all(rating.denominator.isnull().sum()==rating.numerator.isnull().sum())
# there are 17 rows I did not catch their rating from the text
# Out:
# True

# %%
for i,k in enumerate((rating[rating.numerator.isnull()]).text):
    text=(rating[rating.numerator.isnull()]).text.iloc[i]
    print(i, text)
# take a look that all those 17 rows of text
# all of them don't contain rating information
# Out:
# 0 @Jack_Septic_Eye I'd need a few more pics to polish a full analysis, but based on the good boy content above I'm leaning towards
# 1 @Marc_IRL pixelated af
# 2 @xianmcguire @Jenna_Marbles Kardashians wouldn't be famous if as a society we didn't place enormous value on what they do. The dogs are very deserving of their
# 3 @s8n You tried very hard to portray this good boy as not so good, but you have ultimately failed. His goodness shines through.
# 4 .@breaannanicolee PUPDATE: Cannon has a heart on his nose. Pupgraded to a
# 5 @markhoppus
# 6 @bragg6of8 @Andy_Pace_ we are still looking for the first
# 7 @docmisterio account started on
# 8 @UNC can confirm
# 9 @HistoryInPics
# 10 I've been informed by multiple sources that this is actually a dog elf who's tired from helping Santa all night. Pupgraded to
# 11 PUPDATE: I've been informed that Augie was actually bringing his family these flowers when he tripped. Very good boy. Pupgraded to
# 12 @TheEllenShow I'm not sure if you know this but that doggo right there is a
# 13 @mount_alex3
# 14 PUPDATE: just noticed this dog has some extra legs. Very advanced. Revolutionary af. Upgraded to a
# 15 After getting lost in Reese's eyes for several minutes we're going to upgrade him to a
# 16 After countless hours of research and hundreds of formula alterations we have concluded that Dug should be bumped to an

# %%
rating = rating.loc[~rating.numerator.isnull(),:]

# %%
rating[['numerator','denominator']]=rating[['numerator','denominator']].astype('int64')
# Out:
# /opt/conda/lib/python3.6/site-packages/pandas/core/frame.py:3140: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[k1] = value[k2]

# %%
np.all(rating.numerator==rating.rating_numerator)
# Out:
# True

# %%
# except for 17 rows of text without rating information,
# all other rating information in the text column and in the rating_numerator, rating_denomiator match each other

# %% [markdown]
# ## Save the dataframe

# %%
df.to_csv('twitter_archive_master.csv', index=False)

# %% [markdown]
# ## Analysis

# %% [markdown]
# ### Rating characteristics

# %%
# find the outliers
rating = df.rating_numerator/df.rating_denominator
upper=rating.quantile(0.75)
lower=rating.quantile(0.25)
IQR=upper-lower
boundary=upper+1.5*IQR
boundary
# Out:
# 1.5

# %%
# plot the rating without outliers
rating.iloc[np.where(rating<1.5)].hist();

# %%
# 11 data points are outliers
rating.loc[rating>=1.5]
# Out:
# 55        1.700000
# 188      42.000000
# 189      66.600000
# 290      18.200000
# 291       1.500000
# 516       3.428571
# 695       7.500000
# 763       2.700000
# 979     177.600000
# 1712      2.600000
# 2074     42.000000
# dtype: float64

# %%
# the ratio of numerator greater than denominator
rating_greater_than_one=(rating>1).sum()/len(rating)

# %%
rating_not_greater_than_one=(rating<=1).sum()/len(rating)

# %%
rating_greater_than_one, rating_not_greater_than_one
# Out:
# (0.59649930907415938, 0.40350069092584062)

# %%
# plot and compare these two ratios
locations=[1,2]
heights=[rating_greater_than_one, rating_not_greater_than_one]
labels = ['rating>1', 'rating<=1']
plt.bar(locations, heights, tick_label=labels)
plt.title('rating more than 1 vs rating no more than one')
plt.xlabel('rating')
plt.ylabel('ratio');

# %% [markdown]
# ### Relationship of favorites, retweets, and dog_stage

# %%
# grasp the three columns I want to use
df1=df[['favorites','retweets','dog_stage']].copy()

# %%
plt.figure(figsize=(12,6))
sns.scatterplot(x='retweets',y='favorites', data=df1, hue='dog_stage')
# as expected, favorites and retweets are positively related
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-283-e92f039d2bc8> in <module>()
#       1 plt.figure(figsize=(12,6))
# ----> 2 sns.scatterplot(x='retweets',y='favorites', data=df1, hue='dog_stage')
#       3 # as expected, favorites and retweets are positively related
#
# AttributeError: module 'seaborn' has no attribute 'scatterplot'

# %%
# zoom in to take a closer look at how different dog stages are distributed
plt.figure(figsize=(12,6))
sns.scatterplot(x='retweets',y='favorites', data=df1, hue='dog_stage')
plt.xlim(0,15000)
plt.ylim(0,40000)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-280-5be4b812d451> in <module>()
#       1 # zoom in to take a closer look at how different dog stages are distributed
#       2 plt.figure(figsize=(12,6))
# ----> 3 sns.scatterplot(x='retweets',y='favorites', data=df1, hue='dog_stage')
#       4 plt.xlim(0,15000)
#       5 plt.ylim(0,40000)
#
# AttributeError: module 'seaborn' has no attribute 'scatterplot'

# %%
plt.figure(figsize=(10,10))
sns.scatterplot(x='retweets',y='favorites', data=df1, hue='dog_stage')
plt.xlim(0,3000)
plt.ylim(0,10000)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-281-4f941ed32d5f> in <module>()
#       1 plt.figure(figsize=(10,10))
# ----> 2 sns.scatterplot(x='retweets',y='favorites', data=df1, hue='dog_stage')
#       3 plt.xlim(0,3000)
#       4 plt.ylim(0,10000)
#
# AttributeError: module 'seaborn' has no attribute 'scatterplot'

# %%
df1.dog_stage.value_counts().plot.bar()
plt.xticks(rotation=0);
# most of the data points have no dog_stage label, doggo and pupper are the majority among all those woth label
# it seems that doggo are more sparsely distributed and pupper more densely distributed from the graph above
# since pupper seems to be clustered in left lower part of the graph, 
# I guess pupper label might have some ability to predict how many favorites the post will get
# I'll testify this guess by using statistical model

# %%
import statsmodels.api as sm
df1['intercept']=1
df1[['doggo','duplicated','floofer','pupper','puppo']]=pd.get_dummies(df1.dog_stage).drop('None',axis=1)
lm = sm.OLS(df1['favorites'], df1[['retweets','doggo','duplicated','floofer','pupper','puppo','intercept']])
result=lm.fit()
result.summary()
# Out:
# /opt/conda/lib/python3.6/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              favorites   R-squared:                       0.833
# Model:                            OLS   Adj. R-squared:                  0.833
# Method:                 Least Squares   F-statistic:                     1804.
# Date:                Sun, 25 Oct 2020   Prob (F-statistic):               0.00
# Time:                        03:05:44   Log-Likelihood:                -21534.
# No. Observations:                2171   AIC:                         4.308e+04
# Df Residuals:                    2164   BIC:                         4.312e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# retweets       2.3641      0.023    101.950      0.000       2.319       2.410
# doggo         67.2473    586.567      0.115      0.909   -1083.045    1217.540
# duplicated   907.6321   1427.009      0.636      0.525   -1890.820    3706.084
# floofer    -1053.1566   1645.333     -0.640      0.522   -4279.755    2173.442
# pupper      -926.6878    348.497     -2.659      0.008   -1610.113    -243.263
# puppo       3525.5324   1015.175      3.473      0.001    1534.712    5516.353
# intercept   2292.6350    129.624     17.687      0.000    2038.434    2546.836
# ==============================================================================
# Omnibus:                      546.204   Durbin-Watson:                   0.840
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            36352.950
# Skew:                          -0.048   Prob(JB):                         0.00
# Kurtosis:                      23.047   Cond. No.                     8.38e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 8.38e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
from patsy import dmatrices
from statsmodels.stats.outliers_influence import variance_inflation_factor
y,X = dmatrices('favorites ~ retweets + doggo + pupper', df1, return_type='dataframe')
vif=pd.DataFrame()
vif['VIF factors']=[variance_inflation_factor(X.values,i) for i,k in enumerate(X)]
vif['Features']=X.columns

# %%
vif
# there aren't multicollinearity problem
# if I set P=0.05 as a thedshold, pupper does not predict how many favorites a post can get as I thought previously, 
# and retweets number is the only feature that predict favorite in a post
# Out:
#    VIF factors   Features
# 0     1.491808  Intercept
# 1     1.022282   retweets
# 2     1.026045      doggo
# 3     1.004278     pupper

# %% [markdown]
# ### Relationship of retweet, favorites, dog_stage and the rating of the dog image

# %%
df2 = df[['favorites','retweets','dog_stage']]
df2=pd.concat([df2, rating], axis=1)
df2.rename(columns={0:'dog_ratings'},inplace=True)

# %%
df2['intercept']=1
df2[['doggo','duplicated','floofer','pupper','puppo']]=pd.get_dummies(df2.dog_stage).drop('None',axis=1)

# %%
lm = sm.OLS(df2['dog_ratings'], df2[['intercept','favorites','retweets','doggo','duplicated','floofer','pupper','puppo']])
result=lm.fit()
result.summary()
# from this analysis, no feature can predict dog_ratings
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            dog_ratings   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.003
# Method:                 Least Squares   F-statistic:                   0.09017
# Date:                Sun, 25 Oct 2020   Prob (F-statistic):              0.999
# Time:                        03:08:27   Log-Likelihood:                -6221.3
# No. Observations:                2171   AIC:                         1.246e+04
# Df Residuals:                    2163   BIC:                         1.250e+04
# Df Model:                           7
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      1.2252      0.120     10.216      0.000       0.990       1.460
# favorites  -3.887e-06   1.86e-05     -0.209      0.834   -4.03e-05    3.26e-05
# retweets    1.983e-05   4.83e-05      0.411      0.681   -7.49e-05       0.000
# doggo         -0.0982      0.507     -0.194      0.846      -1.093       0.897
# duplicated    -0.1430      1.234     -0.116      0.908      -2.563       2.277
# floofer       -0.0757      1.423     -0.053      0.958      -2.866       2.715
# pupper        -0.1652      0.302     -0.547      0.584      -0.757       0.427
# puppo         -0.0658      0.880     -0.075      0.940      -1.792       1.661
# ==============================================================================
# Omnibus:                     6098.194   Durbin-Watson:                   1.860
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):        177029508.030
# Skew:                          35.445   Prob(JB):                         0.00
# Kurtosis:                    1400.141   Cond. No.                     2.45e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.45e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
# as I know from the previous analysis, retweets and favorites are highly correlated
# I'llhave to see their vif
y,X = dmatrices('dog_ratings ~ retweets + favorites + doggo + pupper', df2, return_type='dataframe')
vif=pd.DataFrame()
vif['VIF factors']=[variance_inflation_factor(X.values,i) for i,k in enumerate(X)]
vif['Features']=X.columns

# %%
vif
# to my surprise, no VIF is higher than 10, however, if I try to be stricter, 
# I can argue that VIF of retweets and favorites are more than 5, so I'll remove retweets to see how it works
# Out:
#    VIF factors   Features
# 0     1.713264  Intercept
# 1     5.980489   retweets
# 2     5.967343  favorites
# 3     1.026045      doggo
# 4     1.007871     pupper

# %%
lm = sm.OLS(df2['dog_ratings'], df2[['intercept','favorites','doggo','duplicated','floofer','pupper','puppo']])
result=lm.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            dog_ratings   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.003
# Method:                 Least Squares   F-statistic:                   0.07714
# Date:                Sun, 25 Oct 2020   Prob (F-statistic):              0.998
# Time:                        03:09:06   Log-Likelihood:                -6221.4
# No. Observations:                2171   AIC:                         1.246e+04
# Df Residuals:                    2164   BIC:                         1.250e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      1.2180      0.119     10.267      0.000       0.985       1.451
# favorites   3.056e-06   7.72e-06      0.396      0.692   -1.21e-05    1.82e-05
# doggo         -0.0858      0.506     -0.169      0.865      -1.079       0.907
# duplicated    -0.1403      1.234     -0.114      0.909      -2.560       2.279
# floofer       -0.0629      1.422     -0.044      0.965      -2.852       2.726
# pupper        -0.1591      0.301     -0.528      0.598      -0.750       0.432
# puppo         -0.0774      0.880     -0.088      0.930      -1.803       1.648
# ==============================================================================
# Omnibus:                     6098.852   Durbin-Watson:                   1.861
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):        177161614.444
# Skew:                          35.455   Prob(JB):                         0.00
# Kurtosis:                    1400.662   Cond. No.                     2.32e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.32e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
plt.scatter(x='favorites',y='dog_ratings',data=df2)
# perhaps it is the noises in dog_ratings that interfere with the model prediction

# %%
df3 = df2[df2['dog_ratings']<1.5].copy()
# remove outliers in dog_ratings

# %%
plt.scatter(x='favorites',y='dog_ratings',data=df3)

# %%
# it donesn't look like using linear model is a good choice, but I'll try it out
lm = sm.OLS(df3['dog_ratings'], df3[['intercept','favorites','doggo','duplicated','floofer','pupper','puppo']])
result=lm.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            dog_ratings   R-squared:                       0.156
# Model:                            OLS   Adj. R-squared:                  0.153
# Method:                 Least Squares   F-statistic:                     66.18
# Date:                Sun, 25 Oct 2020   Prob (F-statistic):           1.06e-75
# Time:                        03:10:37   Log-Likelihood:                 380.97
# No. Observations:                2160   AIC:                            -747.9
# Df Residuals:                    2153   BIC:                            -708.2
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      0.9931      0.006    174.862      0.000       0.982       1.004
# favorites   6.863e-06   3.69e-07     18.619      0.000    6.14e-06    7.59e-06
# doggo          0.0731      0.024      3.024      0.003       0.026       0.120
# duplicated     0.0257      0.059      0.436      0.663      -0.090       0.141
# floofer        0.1199      0.068      1.766      0.078      -0.013       0.253
# pupper         0.0312      0.014      2.166      0.030       0.003       0.060
# puppo          0.0684      0.042      1.630      0.103      -0.014       0.151
# ==============================================================================
# Omnibus:                      758.311   Durbin-Watson:                   1.812
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2697.019
# Skew:                          -1.734   Prob(JB):                         0.00
# Kurtosis:                       7.235   Cond. No.                     2.32e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.32e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
# it's better in terms of predicting dog_ratings compared with the previous one with outliers inside the dataframe.
# I noticed that R-squared is only 0.156 meaning only 15% of the data points can be explained by the linear relationship.
# So I'll say none of these features really has a good linear relationship with the ratings that other people gave

# %% [markdown]
# ### Relation between dog prediction and favorites

# %%
df.groupby('p1_dog').mean()['favorites'].round(2)
# Out:
# p1_dog
# False    7773.68
# True     9293.82
# Name: favorites, dtype: float64

# %%
df.groupby('p2_dog').mean()['favorites'].round(2)
# Out:
# p2_dog
# False    7636.14
# True     9320.32
# Name: favorites, dtype: float64

# %%
df.groupby('p3_dog').mean()['favorites'].round(2)
# Out:
# p3_dog
# False    8078.43
# True     9210.86
# Name: favorites, dtype: float64

# %%
# When looking at the three tables, there are no big difference in terms of favorites counts.
# Generally speaking, there are slightly more favorites when the models predict it is a dog in the photo.

# %%
dog_and_favorites = df.groupby(['p1_dog','p2_dog','p3_dog']).mean()['favorites'].round(2)
pd.DataFrame(dog_and_favorites)
# Out:
#                       favorites
# p1_dog p2_dog p3_dog
# False  False  False     7048.88
#               True      8670.13
#        True   False    10087.77
#               True      8271.83
# True   False  False     6642.21
#               True      9512.72
#        True   False     9970.65
#               True      9291.56

# %%
# As they are put together, the results become more inconsistent.
# I expected photo which all three models predict to be not a dog might have fewer mean favorites counts, 
# but it actually has the second fewest favorites counts instead of the fewest.
# The group where all models predict to be a dog doesn't have the highest favorites counts as expected.
# What is worth noting is that in the group where p1/p3 models predict to be not a dog and p2 predict to be a dog 
# has the highest favorites counts among all. I guess there might be outliers in this group.

# %%
df.favorites.plot.box()

# %%
upper = df.favorites.quantile(0.75)
lower = df.favorites.quantile(0.25)
IQR = upper -lower
upper_boundary= upper + 1.5*IQR
upper_boundary
# Out:
# 24870.25

# %%
fav_outliers= df[(df.favorites > upper_boundary)]

# %%
mask1= df.p1_dog==False
mask2= df.p2_dog==True
mask3= df.p3_dog==False
mask=mask1 & mask2 & mask3
fav_outliers_pred = df[(df.favorites > upper_boundary)& mask]
fav_outliers_pred.favorites.count()/df[mask].favorites.count()
# Out:
# 0.15384615384615385

# %%
mask1= df.p1_dog==True
mask2= df.p2_dog==True
mask3= df.p3_dog==False
mask=mask1 & mask2 & mask3
fav_outliers_pred = df[(df.favorites > upper_boundary)& mask]
fav_outliers_pred.favorites.count()/df[mask].favorites.count()
# Out:
# 0.082758620689655171

# %%
mask1= df.p1_dog==True
mask2= df.p2_dog==True
mask3= df.p3_dog==True
mask=mask1 & mask2 & mask3
fav_outliers_pred = df[(df.favorites > upper_boundary)& mask]
fav_outliers_pred.favorites.count()/df[mask].favorites.count()
# Out:
# 0.088113050706566914

# %%
mask1= df.p1_dog==True
mask2= df.p2_dog==False
mask3= df.p3_dog==True
mask=mask1 & mask2 & mask3
fav_outliers_pred = df[(df.favorites > upper_boundary)& mask]
fav_outliers_pred.favorites.count()/df[mask].favorites.count()
# Out:
# 0.070588235294117646

# %%
mask1= df.p1_dog==True
mask2= df.p2_dog==False
mask3= df.p3_dog==False
mask=mask1 & mask2 & mask3
fav_outliers_pred = df[(df.favorites > upper_boundary)& mask]
fav_outliers_pred.favorites.count()/df[mask].favorites.count()
# Out:
# 0.069767441860465115

# %%
mask1= df.p1_dog==False
mask2= df.p2_dog==True
mask3= df.p3_dog==True
mask=mask1 & mask2 & mask3
fav_outliers_pred = df[(df.favorites > upper_boundary)& mask]
fav_outliers_pred.favorites.count()/df[mask].favorites.count()
# Out:
# 0.063157894736842107

# %%
mask1= df.p1_dog==False
mask2= df.p2_dog==False
mask3= df.p3_dog==True
mask=mask1 & mask2 & mask3
fav_outliers_pred = df[(df.favorites > upper_boundary)& mask]
fav_outliers_pred.favorites.count()/df[mask].favorites.count()
# Out:
# 0.064516129032258063

# %%
mask1= df.p1_dog==False
mask2= df.p2_dog==False
mask3= df.p3_dog==False
mask=mask1 & mask2 & mask3
fav_outliers_pred = df[(df.favorites > upper_boundary)& mask]
fav_outliers_pred.favorites.count()/df[mask].favorites.count()
# Out:
# 0.068181818181818177

# %%
# it looks like my assunption is right that p1:False/p2:True/p3:False group has around two times more outliers than other group
# and that can explain why it has abnormally high amount of mean favorites counts
